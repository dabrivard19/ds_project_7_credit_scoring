# %% [markdown]
# # 02 — Score métier & seuil optimal

# %% [markdown]
# ## On définit : coût = 10×FN + 1×FP, puis on calcule le seuil minimisant le coût

# %% [markdown]
# ### - fichier: src/metrics.py

# %% [markdown]
# ## Seuil optimal: seuil pour lequel le score métier est minimal

# %% [markdown]
# ### - fichier: src/metrics.py
